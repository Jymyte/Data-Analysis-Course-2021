# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
projectid = 'data-analysis-'

# %%
sql = """
#standardSQL
SELECT
*
FROM
`bigquery-public-data.world_bank_global_population.population_by_country`
"""

data = pd.read_gbq(sql,projectid)

# %%
data2 = data[(data.country == "Sweden") | (data.country == "Australia")]
#print(data2)
data2T = data2.T
#print(data2T)
data2T.info()
#print(data2T.index[2:].values)
print(data2T[133])
#data2T.info()

plt.figure(num=None, figsize=(10, 5), dpi=100, facecolor='w', edgecolor='k')
plt.ylim([0,10e6])
plt.bar(data2T.index[2:], data2T[133])
#wide_data = px.data2.citizens_wide()
#print(data2.values)

#fig = px.bar(data2, x=data2[1:2], y="citizens")
#fig.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, country to year_2019
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   133     61 non-null     object
#  1   248     61 non-null     object
# dtypes: object(2)
# memory usage: 3.5+ KB
# country          Australia
# country_code           AUS
# year_1960       10276477.0
# year_1961       10483000.0
# year_1962       10742000.0
#                    ...
# year_2015       23815995.0
# year_2016       24190907.0
# year_2017       24601860.0
# year_2018       24992369.0
# year_2019              NaN
# Name: 133, Length: 62, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3496/1898336015.py in <module>
#      10 plt.figure(num=None, figsize=(10, 5), dpi=100, facecolor='w', edgecolor='k')
#      11 plt.ylim([0,10e6])
# ...
