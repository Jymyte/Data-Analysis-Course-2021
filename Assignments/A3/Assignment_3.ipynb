# %%
import pandas as pd
import numpy as np


data = pd.read_csv("titanic_for_exercise.csv")

# %%
#data.column_name.str.partition("x")[0]

#data.Name.str.partition(" ")[0].value_counts()
#data[data.Name.str.partition(" ")[0] == 'Master.'].Age.value_counts()
data[data.columns]
#data.info()
#data[data.Fare < 0].value_counts()
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     3.0                             Mr. Owen Harris Braund
# 1         1.0     1.0  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1.0     3.0                              Miss. Laina Heikkinen
# 3         1.0     1.0        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0.0     3.0                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882       0.0     2.0                               Rev. Juozas Montvila
# 883       1.0     1.0                        Miss. Margaret Edith Graham
# 884       0.0     3.0                     Miss. Catherine Helen Johnston
# 885       1.0     1.0                               Mr. Karl Howell Behr
# 886       0.0     3.0                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
data.Name.value_counts()
# Out:
# Mr. Owen Harris Braund            1
# Sir. Cosmo Edmund Duff Gordon     1
# Mr. Eliezer Gilinski              1
# Mr. Joseph Murdlin                1
# Mr. Matti Rintamaki               1
#                                  ..
# Mr. Bernard McCoy                 1
# Mr. William Cahoone Jr Johnson    1
# Miss. Nora A Keane                1
# Mr. Howard Hugh Williams          1
# Mr. Patrick Dooley                1
# Name: Name, Length: 886, dtype: int64

# %%
#Searching for missing values

#data.loc[:, data.isnull().any()].columns
#data.dropna()
data[data.Name.dtype == "Float64"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# ...
